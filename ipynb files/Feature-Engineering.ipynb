# %% [markdown]
# #### Training Set Preprocessing

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.model_selection import train_test_split
# %matplotlib inline

# %%
# importing the dataset
dataset = pd.read_csv("../Data/credit_risk_dataset.csv")

# %% [markdown]
# #### Splitting the datasets

# %% [markdown]
# Before we start tampering with the dataset we first need to split the dataset into train and test sets in order to prevent data leakage.

# %%
y = dataset['loan_status']
X = dataset.drop(['loan_status'],axis=1)

# %%
print(y.shape,X.shape)
# Out:
# (32581,) (32581, 11)

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, shuffle=True, random_state=42, test_size=.2)

# %%
print(X_train.shape, y_train.shape, X_test.shape, y_test.shape)
# Out:
# (26064, 11) (26064,) (6517, 11) (6517,)

# %%
train_data = pd.concat([X_train,y_train],axis=1)
test_data = pd.concat([X_test,y_test],axis=1)

# %% [markdown]
# #### Handling missing values

# %% [markdown]
# The missing values are pretty less relative to the amount of data so simply imputing the data is fine. We shall impute the missing values with the respective median value of the column.

# %%
def features_with_na(dataset):
    data = dataset.copy()
    na_features= [feature for feature in dataset.columns if dataset[feature].isnull().sum()>0]
    return na_features

# %%
na_features = features_with_na(train_data)
na_features
# Out:
# ['person_emp_length', 'loan_int_rate']

# %%
def imputer(columns,dataset):
    for column in columns:
        median = dataset[column].median()
        dataset[column].fillna(median,inplace=True)
    return dataset

# %%
train_data = imputer(na_features,train_data)

# %%
train_data.isnull().sum()
# Out:
# person_age                    0
# person_income                 0
# person_home_ownership         0
# person_emp_length             0
# loan_intent                   0
# loan_grade                    0
# loan_amnt                     0
# loan_int_rate                 0
# loan_percent_income           0
# cb_person_default_on_file     0
# cb_person_cred_hist_length    0
# loan_status                   0
# dtype: int64

# %%
train_data.head()
# Out:
#        person_age  person_income person_home_ownership  person_emp_length  \
# 32377          64          46000                  RENT                2.0
# 1338           26          26000                   OWN                0.0
# 7047           23          51000              MORTGAGE                3.0
# 8225           22          56004              MORTGAGE                6.0
# 7178           24          79000                  RENT                3.0
#
#              loan_intent loan_grade  loan_amnt  loan_int_rate  \
# 32377           PERSONAL          C       4800          11.09
# 1338   DEBTCONSOLIDATION          E       8500          16.45
# 7047            PERSONAL          C      16000          13.11
# 8225             MEDICAL          A       6000           7.88
# 7178            PERSONAL          C       7000          12.54
#
#        loan_percent_income cb_person_default_on_file  \
# 32377                 0.10                         Y
# 1338                  0.33                         N
# 7047                  0.31                         Y
# 8225                  0.11                         N
# 7178                  0.09                         N
#
#        cb_person_cred_hist_length  loan_status
# 32377                          24            0
# 1338                            3            1
# 7047                            3            0
# 8225                            4            0
# 7178                            3            0

# %% [markdown]
# #### Handling outliers

# %%
def find_numerical_features(dataset):
    numerical_features = [feature for feature in dataset.columns if dataset[feature].dtype != 'O' and feature != 'loan_status']
    return numerical_features

# %%
numerical_features = find_numerical_features(train_data)
numerical_features
# Out:
# ['person_age',
#  'person_income',
#  'person_emp_length',
#  'loan_amnt',
#  'loan_int_rate',
#  'loan_percent_income',
#  'cb_person_cred_hist_length']

# %%
def detect_and_replace_outliers(features,dataset):
    dataframe = dataset.copy()
    for column in features:
        data = dataframe[column]
        data2 = sorted(data)
        q1 = np.percentile(data2,25)
        q3 = np.percentile(data2,75)
        IQR = q3-q1
        lower_bound = q1 - (1.5*IQR)
        upper_bound = q3 + (1.5*IQR)
        print(f'Column : {column}',np.round(lower_bound,5),np.round(upper_bound,5))
        values = []
        for i in data:
            if i<lower_bound or i>upper_bound:
                i = np.median(data)
                values.append(i)
                continue
            else:
                values.append(i)
        data = values
        dataframe[column] = data
    return dataframe

# %%
demo = detect_and_replace_outliers(numerical_features,train_data)
# Out:
# Column : person_age 12.5 40.5
# Column : person_income -21750.0 140250.0
# Column : person_emp_length -5.5 14.5
# Column : loan_amnt -5875.0 23125.0
# Column : loan_int_rate 1.56 20.04
# Column : loan_percent_income -0.12 0.44
# Column : cb_person_cred_hist_length -4.5 15.5

# %%
demo.describe()
# Out:
#          person_age  person_income  person_emp_length     loan_amnt  \
# count  26064.000000   26064.000000       26064.000000  26064.000000
# mean      26.781768   58559.615216           4.404428   8648.812538
# std        4.428679   26903.138347           3.353342   4880.118592
# min       20.000000    4000.000000           0.000000    500.000000
# 25%       23.000000   39000.000000           2.000000   5000.000000
# 50%       26.000000   55000.000000           4.000000   8000.000000
# 75%       29.000000   74000.000000           6.000000  12000.000000
# max       40.000000  140004.000000          14.000000  23100.000000
#
#        loan_int_rate  loan_percent_income  cb_person_cred_hist_length  \
# count   26064.000000         26064.000000                26064.000000
# mean       10.987761             0.163085                    5.321017
# std         3.038411             0.094802                    3.227007
# min         5.420000             0.000000                    2.000000
# 25%         8.490000             0.090000                    3.000000
# 50%        10.990000             0.150000                    4.000000
# 75%        13.110000             0.220000                    7.000000
# max        20.030000             0.440000                   15.000000
#
#         loan_status
# count  26064.000000
# mean       0.217273
# std        0.412398
# min        0.000000
# 25%        0.000000
# 50%        0.000000
# 75%        0.000000
# max        1.000000

# %%
train_data.describe()
# Out:
#          person_age  person_income  person_emp_length     loan_amnt  \
# count  26064.000000   2.606400e+04       26064.000000  26064.000000
# mean      27.764695   6.617184e+04           4.765577   9601.073320
# std        6.392500   6.359933e+04           4.054371   6315.753396
# min       20.000000   4.000000e+03           0.000000    500.000000
# 25%       23.000000   3.900000e+04           2.000000   5000.000000
# 50%       26.000000   5.500000e+04           4.000000   8000.000000
# 75%       30.000000   7.950000e+04           7.000000  12250.000000
# max      144.000000   6.000000e+06         123.000000  35000.000000
#
#        loan_int_rate  loan_percent_income  cb_person_cred_hist_length  \
# count   26064.000000         26064.000000                26064.000000
# mean       11.008203             0.170446                    5.816720
# std         3.071511             0.106991                    4.054342
# min         5.420000             0.000000                    2.000000
# 25%         8.490000             0.090000                    3.000000
# 50%        10.990000             0.150000                    4.000000
# 75%        13.110000             0.230000                    8.000000
# max        22.480000             0.780000                   30.000000
#
#         loan_status
# count  26064.000000
# mean       0.217273
# std        0.412398
# min        0.000000
# 25%        0.000000
# 50%        0.000000
# 75%        0.000000
# max        1.000000

# %% [markdown]
# We can clearly notice that outliers have been significantly removed. For visual representation one can plot boxplots to view the outliers.

# %%
train_data = demo.copy()

# %% [markdown]
# Adding income slabs for all the people

# %%
demo.head()
# Out:
#        person_age  person_income person_home_ownership  person_emp_length  \
# 32377        26.0        46000.0                  RENT                2.0
# 1338         26.0        26000.0                   OWN                0.0
# 7047         23.0        51000.0              MORTGAGE                3.0
# 8225         22.0        56004.0              MORTGAGE                6.0
# 7178         24.0        79000.0                  RENT                3.0
#
#              loan_intent loan_grade  loan_amnt  loan_int_rate  \
# 32377           PERSONAL          C     4800.0          11.09
# 1338   DEBTCONSOLIDATION          E     8500.0          16.45
# 7047            PERSONAL          C    16000.0          13.11
# 8225             MEDICAL          A     6000.0           7.88
# 7178            PERSONAL          C     7000.0          12.54
#
#        loan_percent_income cb_person_default_on_file  \
# 32377                 0.10                         Y
# 1338                  0.33                         N
# 7047                  0.31                         Y
# 8225                  0.11                         N
# 7178                  0.09                         N
#
#        cb_person_cred_hist_length  loan_status
# 32377                         4.0            0
# 1338                          3.0            1
# 7047                          3.0            0
# 8225                          4.0            0
# 7178                          3.0            0

# %%
train_data.head()
# Out:
#        person_age  person_income person_home_ownership  person_emp_length  \
# 32377        26.0        46000.0                  RENT                2.0
# 1338         26.0        26000.0                   OWN                0.0
# 7047         23.0        51000.0              MORTGAGE                3.0
# 8225         22.0        56004.0              MORTGAGE                6.0
# 7178         24.0        79000.0                  RENT                3.0
#
#              loan_intent loan_grade  loan_amnt  loan_int_rate  \
# 32377           PERSONAL          C     4800.0          11.09
# 1338   DEBTCONSOLIDATION          E     8500.0          16.45
# 7047            PERSONAL          C    16000.0          13.11
# 8225             MEDICAL          A     6000.0           7.88
# 7178            PERSONAL          C     7000.0          12.54
#
#        loan_percent_income cb_person_default_on_file  \
# 32377                 0.10                         Y
# 1338                  0.33                         N
# 7047                  0.31                         Y
# 8225                  0.11                         N
# 7178                  0.09                         N
#
#        cb_person_cred_hist_length  loan_status
# 32377                         4.0            0
# 1338                          3.0            1
# 7047                          3.0            0
# 8225                          4.0            0
# 7178                          3.0            0

# %%
# function to add income slabs in the dataset
def add_income_slab(dataset):
    q1 = np.percentile(dataset.person_income,33)
    q2 = np.percentile(dataset.person_income,66)
    income_slabs = []
    for income in dataset.person_income.values:
        if income<=q1:
            income_slabs.append('lower')
        elif income>q1 and income<=q2:
            income_slabs.append('middle')
        else:
            income_slabs.append('upper')
    dataset['income_slab'] = income_slabs
    return dataset

# %%
train_data = add_income_slab(train_data)
train_data.head()
# Out:
#        person_age  person_income person_home_ownership  person_emp_length  \
# 32377        26.0        46000.0                  RENT                2.0
# 1338         26.0        26000.0                   OWN                0.0
# 7047         23.0        51000.0              MORTGAGE                3.0
# 8225         22.0        56004.0              MORTGAGE                6.0
# 7178         24.0        79000.0                  RENT                3.0
#
#              loan_intent loan_grade  loan_amnt  loan_int_rate  \
# 32377           PERSONAL          C     4800.0          11.09
# 1338   DEBTCONSOLIDATION          E     8500.0          16.45
# 7047            PERSONAL          C    16000.0          13.11
# 8225             MEDICAL          A     6000.0           7.88
# 7178            PERSONAL          C     7000.0          12.54
#
#        loan_percent_income cb_person_default_on_file  \
# 32377                 0.10                         Y
# 1338                  0.33                         N
# 7047                  0.31                         Y
# 8225                  0.11                         N
# 7178                  0.09                         N
#
#        cb_person_cred_hist_length  loan_status income_slab
# 32377                         4.0            0      middle
# 1338                          3.0            1       lower
# 7047                          3.0            0      middle
# 8225                          4.0            0      middle
# 7178                          3.0            0       upper

# %% [markdown]
# #### Log transformation of the non Gaussian distributions of numerical features

# %%
def log_transformation(features, dataset):
    data = dataset.copy()
    for feature in features:
        if 0 in data[feature].unique():
            pass
        else:
            data[feature] = np.log(dataset[feature])
    return data

# %%
demo = log_transformation(numerical_features,train_data)

# %%
demo.describe()
# Out:
#          person_age  person_income  person_emp_length     loan_amnt  \
# count  26064.000000   26064.000000       26064.000000  26064.000000
# mean       3.275042      10.867479           4.404428      8.881418
# std        0.156509       0.487163           3.353342      0.651550
# min        2.995732       8.294050           0.000000      6.214608
# 25%        3.135494      10.571317           2.000000      8.517193
# 50%        3.258097      10.915088           4.000000      8.987197
# 75%        3.367296      11.211820           6.000000      9.392662
# max        3.688879      11.849426          14.000000     10.047588
#
#        loan_int_rate  loan_percent_income  cb_person_cred_hist_length  \
# count   26064.000000         26064.000000                26064.000000
# mean        2.356117             0.163085                    1.501581
# std         0.291264             0.094802                    0.578727
# min         1.690096             0.000000                    0.693147
# 25%         2.138889             0.090000                    1.098612
# 50%         2.396986             0.150000                    1.386294
# 75%         2.573375             0.220000                    1.945910
# max         2.997231             0.440000                    2.708050
#
#         loan_status
# count  26064.000000
# mean       0.217273
# std        0.412398
# min        0.000000
# 25%        0.000000
# 50%        0.000000
# 75%        0.000000
# max        1.000000

# %%
train_data = demo.copy()

# %%
train_data.head()
# Out:
#        person_age  person_income person_home_ownership  person_emp_length  \
# 32377    3.258097      10.736397                  RENT                2.0
# 1338     3.258097      10.165852                   OWN                0.0
# 7047     3.135494      10.839581              MORTGAGE                3.0
# 8225     3.091042      10.933178              MORTGAGE                6.0
# 7178     3.178054      11.277203                  RENT                3.0
#
#              loan_intent loan_grade  loan_amnt  loan_int_rate  \
# 32377           PERSONAL          C   8.476371       2.406044
# 1338   DEBTCONSOLIDATION          E   9.047821       2.800325
# 7047            PERSONAL          C   9.680344       2.573375
# 8225             MEDICAL          A   8.699515       2.064328
# 7178            PERSONAL          C   8.853665       2.528924
#
#        loan_percent_income cb_person_default_on_file  \
# 32377                 0.10                         Y
# 1338                  0.33                         N
# 7047                  0.31                         Y
# 8225                  0.11                         N
# 7178                  0.09                         N
#
#        cb_person_cred_hist_length  loan_status income_slab
# 32377                    1.386294            0      middle
# 1338                     1.098612            1       lower
# 7047                     1.098612            0      middle
# 8225                     1.386294            0      middle
# 7178                     1.098612            0       upper

# %% [markdown]
# #### Label encoding the categorical features

# %%
from sklearn.preprocessing import LabelEncoder

# %%
LabelEncoder = LabelEncoder()

# %%
def find_categorical_features(dataset):
    categorical_features = [feature for feature in dataset.columns if dataset[feature].dtype == 'O']
    return categorical_features

# %%
categorical_features = find_categorical_features(train_data)
categorical_features
# Out:
# ['person_home_ownership',
#  'loan_intent',
#  'loan_grade',
#  'cb_person_default_on_file',
#  'income_slab']

# %%
df = train_data.copy()

# %%
for feature in categorical_features:
    df[feature] = LabelEncoder.fit_transform(df[feature])

# %%
df.head()
# Out:
#        person_age  person_income  person_home_ownership  person_emp_length  \
# 32377    3.258097      10.736397                      3                2.0
# 1338     3.258097      10.165852                      2                0.0
# 7047     3.135494      10.839581                      0                3.0
# 8225     3.091042      10.933178                      0                6.0
# 7178     3.178054      11.277203                      3                3.0
#
#        loan_intent  loan_grade  loan_amnt  loan_int_rate  loan_percent_income  \
# 32377            4           2   8.476371       2.406044                 0.10
# 1338             0           4   9.047821       2.800325                 0.33
# 7047             4           2   9.680344       2.573375                 0.31
# 8225             3           0   8.699515       2.064328                 0.11
# 7178             4           2   8.853665       2.528924                 0.09
#
#        cb_person_default_on_file  cb_person_cred_hist_length  loan_status  \
# 32377                          1                    1.386294            0
# 1338                           0                    1.098612            1
# 7047                           1                    1.098612            0
# 8225                           0                    1.386294            0
# 7178                           0                    1.098612            0
#
#        income_slab
# 32377            1
# 1338             0
# 7047             1
# 8225             1
# 7178             2

# %%
train_data = df.copy()

# %% [markdown]
# Scaling the features

# %%
from sklearn.preprocessing import StandardScaler

# %%
scaler = StandardScaler()

# %%
train_data_columns =  train_data.columns
y = train_data.iloc[:,-2]
df = train_data.drop('loan_status',axis=1)

# %%
df.head()
# Out:
#        person_age  person_income  person_home_ownership  person_emp_length  \
# 32377    3.258097      10.736397                      3                2.0
# 1338     3.258097      10.165852                      2                0.0
# 7047     3.135494      10.839581                      0                3.0
# 8225     3.091042      10.933178                      0                6.0
# 7178     3.178054      11.277203                      3                3.0
#
#        loan_intent  loan_grade  loan_amnt  loan_int_rate  loan_percent_income  \
# 32377            4           2   8.476371       2.406044                 0.10
# 1338             0           4   9.047821       2.800325                 0.33
# 7047             4           2   9.680344       2.573375                 0.31
# 8225             3           0   8.699515       2.064328                 0.11
# 7178             4           2   8.853665       2.528924                 0.09
#
#        cb_person_default_on_file  cb_person_cred_hist_length  income_slab
# 32377                          1                    1.386294            1
# 1338                           0                    1.098612            0
# 7047                           1                    1.098612            1
# 8225                           0                    1.386294            1
# 7178                           0                    1.098612            2

# %%
df = pd.DataFrame(scaler.fit_transform(df),index=train_data.index)

# %%
df.head()
# Out:
#              0         1         2         3         4         5         6   \
# 32377 -0.108271 -0.269079  0.924046 -0.717038  0.849923  0.674664 -0.621678
# 1338  -0.108271 -1.440260  0.226253 -1.313469 -1.459482  2.394920  0.255402
# 7047  -0.891641 -0.057268 -1.169333 -0.418822  0.849923  0.674664  1.226217
# 8225  -1.175666  0.134863 -1.169333  0.475825  0.272572 -1.045591 -0.279190
# 7178  -0.619706  0.841057  0.924046 -0.418822  0.849923  0.674664 -0.042595
#
#              7         8         9         10        11
# 32377  0.171418 -0.665450  2.174477 -0.199210  0.007903
# 1338   1.525138  1.760709 -0.459881 -0.696314 -1.225607
# 7047   0.745931  1.549739  2.174477 -0.696314  0.007903
# 8225  -1.001823 -0.559965 -0.459881 -0.199210  0.007903
# 7178   0.593311 -0.770936 -0.459881 -0.696314  1.241414

# %%
df.insert(11, 'loan_status', y)

# %%
df.columns = train_data_columns

# %%
df.head()
# Out:
#        person_age  person_income  person_home_ownership  person_emp_length  \
# 32377   -0.108271      -0.269079               0.924046          -0.717038
# 1338    -0.108271      -1.440260               0.226253          -1.313469
# 7047    -0.891641      -0.057268              -1.169333          -0.418822
# 8225    -1.175666       0.134863              -1.169333           0.475825
# 7178    -0.619706       0.841057               0.924046          -0.418822
#
#        loan_intent  loan_grade  loan_amnt  loan_int_rate  loan_percent_income  \
# 32377     0.849923    0.674664  -0.621678       0.171418            -0.665450
# 1338     -1.459482    2.394920   0.255402       1.525138             1.760709
# 7047      0.849923    0.674664   1.226217       0.745931             1.549739
# 8225      0.272572   -1.045591  -0.279190      -1.001823            -0.559965
# 7178      0.849923    0.674664  -0.042595       0.593311            -0.770936
#
#        cb_person_default_on_file  cb_person_cred_hist_length  loan_status  \
# 32377                   2.174477                   -0.199210            0
# 1338                   -0.459881                   -0.696314            1
# 7047                    2.174477                   -0.696314            0
# 8225                   -0.459881                   -0.199210            0
# 7178                   -0.459881                   -0.696314            0
#
#        income_slab
# 32377     0.007903
# 1338     -1.225607
# 7047      0.007903
# 8225      0.007903
# 7178      1.241414

# %%
train_data = df.copy()

# %%
train_data.head()
# Out:
#        person_age  person_income  person_home_ownership  person_emp_length  \
# 32377   -0.108271      -0.269079               0.924046          -0.717038
# 1338    -0.108271      -1.440260               0.226253          -1.313469
# 7047    -0.891641      -0.057268              -1.169333          -0.418822
# 8225    -1.175666       0.134863              -1.169333           0.475825
# 7178    -0.619706       0.841057               0.924046          -0.418822
#
#        loan_intent  loan_grade  loan_amnt  loan_int_rate  loan_percent_income  \
# 32377     0.849923    0.674664  -0.621678       0.171418            -0.665450
# 1338     -1.459482    2.394920   0.255402       1.525138             1.760709
# 7047      0.849923    0.674664   1.226217       0.745931             1.549739
# 8225      0.272572   -1.045591  -0.279190      -1.001823            -0.559965
# 7178      0.849923    0.674664  -0.042595       0.593311            -0.770936
#
#        cb_person_default_on_file  cb_person_cred_hist_length  loan_status  \
# 32377                   2.174477                   -0.199210            0
# 1338                   -0.459881                   -0.696314            1
# 7047                    2.174477                   -0.696314            0
# 8225                   -0.459881                   -0.199210            0
# 7178                   -0.459881                   -0.696314            0
#
#        income_slab
# 32377     0.007903
# 1338     -1.225607
# 7047      0.007903
# 8225      0.007903
# 7178      1.241414

# %%
train_data.to_csv('../Data/data-created/train_data_preprocessed.csv',index=False)

# %% [markdown]
# #### Test Data Preprocessing

# %%
test_data.head()
# Out:
#        person_age  person_income person_home_ownership  person_emp_length  \
# 14668          24          28000                   OWN                6.0
# 24614          27          64000                  RENT                0.0
# 11096          26          72000              MORTGAGE               10.0
# 10424          23          27996                  RENT                7.0
# 26007          30          44500                  RENT                2.0
#
#              loan_intent loan_grade  loan_amnt  loan_int_rate  \
# 14668    HOMEIMPROVEMENT          B      10000          10.37
# 24614           PERSONAL          C      10000          15.27
# 11096          EDUCATION          D      16000            NaN
# 10424  DEBTCONSOLIDATION          A      10000            NaN
# 26007            MEDICAL          E      13000          16.32
#
#        loan_percent_income cb_person_default_on_file  \
# 14668                 0.36                         N
# 24614                 0.16                         Y
# 11096                 0.22                         N
# 10424                 0.36                         N
# 26007                 0.29                         N
#
#        cb_person_cred_hist_length  loan_status
# 14668                           2            0
# 24614                          10            0
# 11096                           3            0
# 10424                           2            1
# 26007                           6            1

# %%
test_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 6517 entries, 14668 to 24385
# Data columns (total 12 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   person_age                  6517 non-null   int64
#  1   person_income               6517 non-null   int64
#  2   person_home_ownership       6517 non-null   object
#  3   person_emp_length           6339 non-null   float64
#  4   loan_intent                 6517 non-null   object
#  5   loan_grade                  6517 non-null   object
#  6   loan_amnt                   6517 non-null   int64
#  7   loan_int_rate               5880 non-null   float64
#  8   loan_percent_income         6517 non-null   float64
#  9   cb_person_default_on_file   6517 non-null   object
#  10  cb_person_cred_hist_length  6517 non-null   int64
#  11  loan_status                 6517 non-null   int64
# dtypes: float64(3), int64(5), object(4)
# memory usage: 661.9+ KB

# %%
test_data.describe()
# Out:
#         person_age  person_income  person_emp_length     loan_amnt  \
# count  6517.000000   6.517000e+03        6339.000000   6517.000000
# mean     27.614240   6.568693e+04           4.799495   9542.569434
# std       6.166234   5.504968e+04           4.273842   6347.622950
# min      20.000000   4.200000e+03           0.000000    700.000000
# 25%      23.000000   3.800000e+04           2.000000   5000.000000
# 50%      26.000000   5.500000e+04           4.000000   8000.000000
# 75%      30.000000   7.900000e+04           7.000000  12000.000000
# max     123.000000   2.039784e+06         123.000000  35000.000000
#
#        loan_int_rate  loan_percent_income  cb_person_cred_hist_length  \
# count    5880.000000          6517.000000                 6517.000000
# mean       11.018027             0.169234                    5.754181
# std         3.286681             0.105942                    4.057562
# min         5.420000             0.000000                    2.000000
# 25%         7.900000             0.090000                    3.000000
# 50%        10.990000             0.150000                    4.000000
# 75%        13.470000             0.230000                    8.000000
# max        23.220000             0.830000                   30.000000
#
#        loan_status
# count  6517.000000
# mean      0.221728
# std       0.415441
# min       0.000000
# 25%       0.000000
# 50%       0.000000
# 75%       0.000000
# max       1.000000

# %%
test_data.isna().sum()
# Out:
# person_age                      0
# person_income                   0
# person_home_ownership           0
# person_emp_length             178
# loan_intent                     0
# loan_grade                      0
# loan_amnt                       0
# loan_int_rate                 637
# loan_percent_income             0
# cb_person_default_on_file       0
# cb_person_cred_hist_length      0
# loan_status                     0
# dtype: int64

# %%
na_features = features_with_na(test_data)
na_features
# Out:
# ['person_emp_length', 'loan_int_rate']

# %%
test_data = imputer(na_features,test_data)

# %%
test_data.isna().all()
# Out:
# person_age                    False
# person_income                 False
# person_home_ownership         False
# person_emp_length             False
# loan_intent                   False
# loan_grade                    False
# loan_amnt                     False
# loan_int_rate                 False
# loan_percent_income           False
# cb_person_default_on_file     False
# cb_person_cred_hist_length    False
# loan_status                   False
# dtype: bool

# %%
numerical_features = find_numerical_features(test_data)

# %%
test_data = detect_and_replace_outliers(numerical_features,test_data)
# Out:
# Column : person_age 12.5 40.5
# Column : person_income -23500.0 140500.0
# Column : person_emp_length -5.5 14.5
# Column : loan_amnt -5500.0 22500.0
# Column : loan_int_rate 1.56 20.04
# Column : loan_percent_income -0.12 0.44
# Column : cb_person_cred_hist_length -4.5 15.5

# %%
test_data.describe()
# Out:
#         person_age  person_income  person_emp_length     loan_amnt  \
# count  6517.000000    6517.000000        6517.000000   6517.000000
# mean     26.751573   58455.863894           4.418751   8532.315483
# std       4.430917   26888.940765           3.345930   4793.466863
# min      20.000000    4200.000000           0.000000    700.000000
# 25%      23.000000   38000.000000           2.000000   5000.000000
# 50%      26.000000   55000.000000           4.000000   8000.000000
# 75%      29.000000   74004.000000           6.000000  11800.000000
# max      40.000000  140304.000000          14.000000  22500.000000
#
#        loan_int_rate  loan_percent_income  cb_person_cred_hist_length  \
# count    6517.000000          6517.000000                  6517.00000
# mean       10.990726             0.162730                     5.22940
# std         3.082156             0.094659                     3.17226
# min         5.420000             0.000000                     2.00000
# 25%         8.490000             0.090000                     3.00000
# 50%        10.990000             0.150000                     4.00000
# 75%        13.110000             0.220000                     7.00000
# max        20.030000             0.440000                    15.00000
#
#        loan_status
# count  6517.000000
# mean      0.221728
# std       0.415441
# min       0.000000
# 25%       0.000000
# 50%       0.000000
# 75%       0.000000
# max       1.000000

# %%
test_data = add_income_slab(test_data)

# %%
test_data.head()
# Out:
#        person_age  person_income person_home_ownership  person_emp_length  \
# 14668        24.0        28000.0                   OWN                6.0
# 24614        27.0        64000.0                  RENT                0.0
# 11096        26.0        72000.0              MORTGAGE               10.0
# 10424        23.0        27996.0                  RENT                7.0
# 26007        30.0        44500.0                  RENT                2.0
#
#              loan_intent loan_grade  loan_amnt  loan_int_rate  \
# 14668    HOMEIMPROVEMENT          B    10000.0          10.37
# 24614           PERSONAL          C    10000.0          15.27
# 11096          EDUCATION          D    16000.0          10.99
# 10424  DEBTCONSOLIDATION          A    10000.0          10.99
# 26007            MEDICAL          E    13000.0          16.32
#
#        loan_percent_income cb_person_default_on_file  \
# 14668                 0.36                         N
# 24614                 0.16                         Y
# 11096                 0.22                         N
# 10424                 0.36                         N
# 26007                 0.29                         N
#
#        cb_person_cred_hist_length  loan_status income_slab
# 14668                         2.0            0       lower
# 24614                        10.0            0      middle
# 11096                         3.0            0       upper
# 10424                         2.0            1       lower
# 26007                         6.0            1      middle

# %%
test_data = log_transformation(numerical_features,test_data)

# %%
test_data.head()
# Out:
#        person_age  person_income person_home_ownership  person_emp_length  \
# 14668    3.178054      10.239960                   OWN                6.0
# 24614    3.295837      11.066638                  RENT                0.0
# 11096    3.258097      11.184421              MORTGAGE               10.0
# 10424    3.135494      10.239817                  RENT                7.0
# 26007    3.401197      10.703244                  RENT                2.0
#
#              loan_intent loan_grade  loan_amnt  loan_int_rate  \
# 14668    HOMEIMPROVEMENT          B   9.210340       2.338917
# 24614           PERSONAL          C   9.210340       2.725890
# 11096          EDUCATION          D   9.680344       2.396986
# 10424  DEBTCONSOLIDATION          A   9.210340       2.396986
# 26007            MEDICAL          E   9.472705       2.792391
#
#        loan_percent_income cb_person_default_on_file  \
# 14668                 0.36                         N
# 24614                 0.16                         Y
# 11096                 0.22                         N
# 10424                 0.36                         N
# 26007                 0.29                         N
#
#        cb_person_cred_hist_length  loan_status income_slab
# 14668                    0.693147            0       lower
# 24614                    2.302585            0      middle
# 11096                    1.098612            0       upper
# 10424                    0.693147            1       lower
# 26007                    1.791759            1      middle

# %%
test_data.describe()
# Out:
#         person_age  person_income  person_emp_length    loan_amnt  \
# count  6517.000000    6517.000000        6517.000000  6517.000000
# mean      3.273899      10.865324           4.418751     8.871309
# std       0.156531       0.487631           3.345930     0.643567
# min       2.995732       8.342840           0.000000     6.551080
# 25%       3.135494      10.545341           2.000000     8.517193
# 50%       3.258097      10.915088           4.000000     8.987197
# 75%       3.367296      11.211874           6.000000     9.375855
# max       3.688879      11.851567          14.000000    10.021271
#
#        loan_int_rate  loan_percent_income  cb_person_cred_hist_length  \
# count    6517.000000          6517.000000                 6517.000000
# mean        2.355214             0.162730                    1.486785
# std         0.295567             0.094659                    0.572291
# min         1.690096             0.000000                    0.693147
# 25%         2.138889             0.090000                    1.098612
# 50%         2.396986             0.150000                    1.386294
# 75%         2.573375             0.220000                    1.945910
# max         2.997231             0.440000                    2.708050
#
#        loan_status
# count  6517.000000
# mean      0.221728
# std       0.415441
# min       0.000000
# 25%       0.000000
# 50%       0.000000
# 75%       0.000000
# max       1.000000

# %%
for feature in categorical_features:
    test_data[feature] = LabelEncoder.fit_transform(test_data[feature])

# %%
test_data.head()
# Out:
#        person_age  person_income  person_home_ownership  person_emp_length  \
# 14668    3.178054      10.239960                      2                6.0
# 24614    3.295837      11.066638                      3                0.0
# 11096    3.258097      11.184421                      0               10.0
# 10424    3.135494      10.239817                      3                7.0
# 26007    3.401197      10.703244                      3                2.0
#
#        loan_intent  loan_grade  loan_amnt  loan_int_rate  loan_percent_income  \
# 14668            2           1   9.210340       2.338917                 0.36
# 24614            4           2   9.210340       2.725890                 0.16
# 11096            1           3   9.680344       2.396986                 0.22
# 10424            0           0   9.210340       2.396986                 0.36
# 26007            3           4   9.472705       2.792391                 0.29
#
#        cb_person_default_on_file  cb_person_cred_hist_length  loan_status  \
# 14668                          0                    0.693147            0
# 24614                          1                    2.302585            0
# 11096                          0                    1.098612            0
# 10424                          0                    0.693147            1
# 26007                          0                    1.791759            1
#
#        income_slab
# 14668            0
# 24614            1
# 11096            2
# 10424            0
# 26007            1

# %%
test_data_columns =  test_data.columns
y = test_data.iloc[:,-2]
df = test_data.drop('loan_status',axis=1)

# %%
df.head()
# Out:
#        person_age  person_income  person_home_ownership  person_emp_length  \
# 14668    3.178054      10.239960                      2                6.0
# 24614    3.295837      11.066638                      3                0.0
# 11096    3.258097      11.184421                      0               10.0
# 10424    3.135494      10.239817                      3                7.0
# 26007    3.401197      10.703244                      3                2.0
#
#        loan_intent  loan_grade  loan_amnt  loan_int_rate  loan_percent_income  \
# 14668            2           1   9.210340       2.338917                 0.36
# 24614            4           2   9.210340       2.725890                 0.16
# 11096            1           3   9.680344       2.396986                 0.22
# 10424            0           0   9.210340       2.396986                 0.36
# 26007            3           4   9.472705       2.792391                 0.29
#
#        cb_person_default_on_file  cb_person_cred_hist_length  income_slab
# 14668                          0                    0.693147            0
# 24614                          1                    2.302585            1
# 11096                          0                    1.098612            2
# 10424                          0                    0.693147            0
# 26007                          0                    1.791759            1

# %%
df = pd.DataFrame(scaler.fit_transform(df),index=df.index)

# %%
df.insert(11, 'loan_status', y)

# %%
df.columns = test_data_columns

# %%
df.head()
# Out:
#        person_age  person_income  person_home_ownership  person_emp_length  \
# 14668   -0.612356      -1.282551               0.224636           0.472625
# 24614    0.140161       0.412874               0.922420          -1.320736
# 11096   -0.100962       0.654434              -1.170933           1.668199
# 10424   -0.884270      -1.282844               0.922420           0.771519
# 26007    0.813310      -0.332406               0.922420          -0.722949
#
#        loan_intent  loan_grade  loan_amnt  loan_int_rate  loan_percent_income  \
# 14668    -0.322812   -0.193472   0.526841      -0.055143             2.084175
# 24614     0.835013    0.653308   0.526841       1.254212            -0.028840
# 11096    -0.901725    1.500089   1.257208       0.141337             0.605064
# 10424    -1.480638   -1.040252   0.526841       0.141337             2.084175
# 26007     0.256100    2.346869   0.934545       1.479224             1.344620
#
#        cb_person_default_on_file  cb_person_cred_hist_length  loan_status  \
# 14668                  -0.473856                   -1.386879            0
# 24614                   2.110345                    1.425608            0
# 11096                  -0.473856                   -0.678331            0
# 10424                  -0.473856                   -1.386879            1
# 26007                  -0.473856                    0.532942            1
#
#        income_slab
# 14668    -1.216936
# 24614     0.004686
# 11096     1.226309
# 10424    -1.216936
# 26007     0.004686

# %%
test_data = df.copy()

# %%
test_data.isna().any().sum()
# Out:
# 0

# %%
test_data.to_csv('../Data/data-created/test_data_preprocessed.csv',index=False)
