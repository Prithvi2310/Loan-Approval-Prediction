# %%
import numpy as np 
import pandas as pd
import pickle
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.metrics import confusion_matrix, accuracy_score, ConfusionMatrixDisplay

# %%
test_data = pd.read_csv('../Data/data-created/test_data_preprocessed.csv')

# %%
X_test = test_data.drop(['loan_status'],axis=1)
y_test = test_data.loan_status

# %%
def metrics(matrix):
    TN = matrix[0,0]
    TP = matrix[1,1]
    FP = matrix[0,1]
    FN = matrix[1,0]
    recall = TP/(TP + FN)
    precision = TP/(TP + FP)
    f1_score = 2*recall*precision/(recall+precision)
    return [recall,precision,f1_score]

# %% [markdown]
# #### Prediction and Analysis of Model Performance
#
# ##### 1) Logistic Regression

# %%
filename = open('../models/logistic_regression','rb')
logistic_regression = pickle.load(filename)

# %%
y_pred = logistic_regression.predict(X_test)

# %%
logistic_confusionMatrix = confusion_matrix(y_test, y_pred, labels=logistic_regression.classes_)

# %%
print(logistic_confusionMatrix)
# Out:
# [[4848  247]
#  [ 773  649]]

# %%
disp = ConfusionMatrixDisplay(logistic_confusionMatrix)
disp.plot()
plt.show()

# %%
logistic_metrics = metrics(logistic_confusionMatrix)
print(logistic_metrics)
# Out:
# [0.45639943741209565, 0.7243303571428571, 0.5599654874892147]

# %% [markdown]
# ##### 2) Gaussian Naive Bayes

# %%
filename = open('../models/gnb','rb')
gnb = pickle.load(filename)

# %%
y_pred = gnb.predict(X_test)

# %%
gnb_confusionMatrix = confusion_matrix(y_test, y_pred, labels=gnb.classes_)

# %%
print(gnb_confusionMatrix)
# Out:
# [[4848  247]
#  [ 773  649]]

# %%
disp = ConfusionMatrixDisplay(gnb_confusionMatrix)
disp.plot()
plt.plot()
# Out:
# []

# %%
gnb_metrics = metrics(gnb_confusionMatrix)
print(gnb_metrics)
# Out:
# [0.45639943741209565, 0.7243303571428571, 0.5599654874892147]
